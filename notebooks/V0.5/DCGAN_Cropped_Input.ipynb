# %% [markdown]
# # DwarfGAN - Deep Learning based Map Design for Dwarf Fortress

# %% [markdown]
# ### Setup and Imports

# %%
""" 

loosely based on example coded provided in Foster, 2019 see:

basic GAN
"G:\Dev\DataScience\GDL_code\models\GAN.py"


"""
# imports
from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Lambda, Activation, BatchNormalization, LeakyReLU, Dropout, ZeroPadding2D, UpSampling2D
from keras.layers.experimental import preprocessing
from keras.models import Model
from keras import backend as K
from keras.optimizers import Adam, RMSprop
from keras.initializers import RandomNormal
from keras.losses import binary_crossentropy

import numpy as np
import os
import datetime
import matplotlib.pyplot as plt
import PIL
import PIL.Image
import pathlib
import tensorflow as tf
import io
import random

#!pip install boto3
import boto3 as b3 


print(f'tensorflow version: {tf.__version__}')
NUM_GPUS = len(tf.config.list_physical_devices('GPU'))
print(f'Number of GPUs found: {NUM_GPUS}')

############### CONFIG ###################

# model name
model_name = 'dwarfgan001'
# folder path to input files (map images)
fpath = r'/data/input'
# folder path to tensorboard output
tboard_dir = '/data/output/tensorboard'
# folder path for saved model output
out_model_dir = '/data/output/models'
# frequency of checkpoint saves (images, model weights) in epochs
checkpoint = 100

##########################################

# NOTE: all extracted map PNGs have been saved on a separate virtual disk mapped to '/data' of the virtual machine in use
data_dir = pathlib.Path(fpath + '/maps')
imgs = list(data_dir.glob('*.png'))
# Out:
# 2.3.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# ### Check available Samples from S3 Bucket

# %%
# Load from Switch S3 bucket
s3 = b3.resource('s3',
                 region_name='ZH',
                 endpoint_url='https://os.zhdk.cloud.switch.ch',
                 aws_access_key_id='',    # needs to be specified. Willfully ommited due to security concerns
                 aws_secret_access_key='' # needs to be specified. Willfully ommited due to security concerns
                 )

# check connection
for bucket in s3.buckets.all():
    print(bucket.name)


obj = s3.Object('storage_hil', 'maps/map_1.png')
# get list of files
my_bucket = s3.Bucket('storage_hil')
filelist = [e.key for e in my_bucket.objects.filter(Prefix='maps/')]
print(f'Found {len(filelist)} images in S3 storage')

# get example file from S3 storage and read as Byte stream
img = io.BytesIO(obj.get()['Body'].read())

# Visualize image from S3 bucket
PIL.Image.open(img)
# Out:
# simmler_qualitai_goldstandard_full
# storage_hil
# Found 119564 images in S3 storage
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2304x2304 at 0x7F2852EAED30>

# %% [markdown]
# ### Data Load and Train / Validation Split

# %% [markdown]
# The map images sourced from the DFMA come in a variety of dimensions. In order to create sample images with constant dimensions, as required by tensors, the 100k input samples were run through a python script to randomly crop 10 1024 x 1024 areas per picture. Of those cropped (sub-)images, only the ones which contain structures were retained. This was achieved by filtering out image crops which only contained two or less different colors. With that, the logic mainly filterd out crops which only contained black. This process resulted in 700'000+ (sub-)image samples.

# %%
# use pre-processed (cropped) 1024x1024 images
data_dir = pathlib.Path(fpath + '/crops')
imgs = list(data_dir.glob('*.png'))
print(f'There are {str(len(imgs))} cropped image samples available')

# show example sample image (cropped to 1024x1024)
print('A random sample input image:')
PIL.Image.open(imgs[random.randint(0,len(imgs))])
# Out:
# There are 726300 cropped image samples available
# A random sample input image:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024 at 0x7F687386BF60>

# %%
# pre-processed (cropped) images are 1024x1024. We will later resize the images to 512x512 due to memory restrictions.
IMAGE_SIZE = (1024, 1024)
BATCH_SIZE = 16


# creating keras datasets for training and validation - refer to https://www.tensorflow.org/tutorials/images/classification
dataset_train = tf.keras.preprocessing.image_dataset_from_directory(  fpath,
                                                                      image_size=IMAGE_SIZE, 
                                                                      batch_size=BATCH_SIZE, 
                                                                      labels=[1.] * len(imgs), # setting all labels to 1 (for 'real')
                                                                      #label_mode=None, # yields float32 type labels
                                                                      seed=42,
                                                                      validation_split=0.1,
                                                                      subset='training'
                                                                    )

dataset_val = tf.keras.preprocessing.image_dataset_from_directory(  fpath,
                                                                    image_size=IMAGE_SIZE, 
                                                                    batch_size=BATCH_SIZE, 
                                                                    labels=[1.] * len(imgs), # setting all labels to 1 (for 'real')
                                                                    #label_mode=None, # yields float32 type labels
                                                                    seed=42,
                                                                    validation_split=0.1,
                                                                    subset='validation'
                                                                    )


# refer to https://www.tensorflow.org/tutorials/images/classification
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = dataset_train.cache().prefetch(buffer_size=BATCH_SIZE)
val_ds = dataset_val.cache().prefetch(buffer_size=BATCH_SIZE)
# Out:
# Found 726300 files belonging to 1 classes.
# Using 653670 files for training.
# Found 726300 files belonging to 1 classes.
# Using 72630 files for validation.

# %% [markdown]
# ### Check Random Sample Dataset

# %%
# Check random images from prepared batches
plt.figure(figsize=(10, 10))
for images, labels in dataset_train.take(1): # take one batch. Here batch_size = 32 examples per batch
    for i in range(9): # show first 9 images of batch
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(f'Image Check {i+1}, label {labels[i]}')
        plt.axis('off')

# %% [markdown]
# ### Discriminator Model Definition

# %%
def discriminator_model():

    # DISCRIMINATOR
    # set input variables to variable width + height. Will be cropped in preprocessing [CURRENTLY FIXED TO 512x512]
    input_dim = (None, None, 3)

    # Input
    d_input = Input(shape=input_dim, name='Discriminator_Input')

    x = preprocessing.Resizing(width=512, 
                               height=512, 
                               name='Preprocessing_Resize'
                              )(d_input) # Resize to 512 x 512 images

    x = preprocessing.Rescaling(scale=1./127.5, 
                                offset=-1,
                                name='Preprocessing_Rescale'
                               )(x) # Rescale values from [0,255] to [-1,1] see https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/Rescaling


    # Conv2D Layer 1
    x = Conv2D(
            filters = 128,
            kernel_size = 5,
            strides = 2,
            padding = 'same',
            name = 'Discriminator_Conv2D_Layer_1'
    )(x)

    # BatchNorm Layer 1
    x = BatchNormalization()(x)

    # Activation 1 - Leaky ReLU
    x = LeakyReLU(alpha = 0.1, name='Activation_1')(x)

    # Dropout 1
    x = Dropout(rate = 0.4)(x)


    # Conv2D Layer 2
    x = Conv2D(
            filters = 128,
            kernel_size = 5,
            strides = 2,
            padding = 'same',
            name = 'Discriminator_Conv2D_Layer_2',
            kernel_initializer = RandomNormal(mean=0., stddev=0.02)
    )(x)

    # BatchNorm Layer 2
    x = BatchNormalization()(x)

    # Activation 2 - Leaky ReLU
    x = LeakyReLU(alpha = 0.1, name='Activation_2')(x)

    # Dropout 2
    x = Dropout(rate = 0.4)(x)


    # Conv2D Layer 3
    x = Conv2D(
            filters = 128,
            kernel_size = 5,
            strides = 2,
            padding = 'same',
            name = 'Discriminator_Conv2D_Layer_3',
            kernel_initializer = RandomNormal(mean=0., stddev=0.02)
    )(x)

    # BatchNorm Layer 3
    x = BatchNormalization()(x)

    # Activation 3 - Leaky ReLU
    x = LeakyReLU(alpha = 0.1, name='Activation_3')(x)

    # Dropout 3
    x = Dropout(rate = 0.4)(x)



    # Conv2D Layer 4
    x = Conv2D(filters = 128,
               kernel_size = 5,
               strides = 2,
               padding = 'same',
               name = 'Discriminator_Conv2D_Layer_4',
               kernel_initializer = RandomNormal(mean=0., stddev=0.02)
    )(x)

    # BatchNorm Layer 4
    x = BatchNormalization()(x)

    # Activation 4 - Leaky ReLU
    x = LeakyReLU(alpha = 0.1, name='Activation_4')(x)

    # Dropout 4
    x = Dropout(rate = 0.4)(x)




    # Conv2D Layer 5
    x = Conv2D(filters = 64,
               kernel_size = 5,
               strides = 2,
               padding = 'same',
               name = 'Discriminator_Conv2D_Layer_5',
               kernel_initializer = RandomNormal(mean=0., stddev=0.02)
    )(x)

    # BatchNorm Layer 5
    x = BatchNormalization()(x)

    # Activation 5 - Leaky ReLU
    x = LeakyReLU(alpha = 0.1, name='Activation_5')(x)

    # Dropout 5
    x = Dropout(rate = 0.4)(x)


    # OUTPUT
    x = Flatten()(x)
    d_output = Dense(1, 
                     activation='sigmoid', 
                     kernel_initializer = RandomNormal(mean=0, stddev=0.02) # random initialization of weights with normal distribution around 0 with small SD
                    )(x)



    # Discriminator Model intialization
    discriminator = Model(d_input, d_output, name='Discriminator')
    
    
    
    return discriminator

# %% [markdown]
# ### Generator Model Definition

# %%
def generator_model():

    # GENERATOR

    # set input variable dimensions. Here we will start out with a vector of length 100 for each sample (sampled from a normal distribution, representing the learned latent space)
    input_dim = (100)

    # Input
    g_input = Input(shape=input_dim, name='Generator_Input')

    # Dense Layer 1
    x = Dense(np.prod([16,16,32]), use_bias=False)(g_input)

    # Batch Norm Layer 1
    x = BatchNormalization(momentum = 0.9)(x)

    # Activation Layer 1
    x = LeakyReLU()(x) # trying leaky ReLU instead of Activation('relu')(x)

    # Reshape into 3D tensor
    x = Reshape((16,16,32))(x)

    # Upsampling Layer 1 + Conv2D Layer1
    x = UpSampling2D()(x)
    x = Conv2D(filters=64, kernel_size=5, padding='same', name='Generator_Conv_Layer_1')(x)

    # Batch Norm Layer 2
    x = BatchNormalization(momentum = 0.9)(x)

    # Activation Layer 2
    x = LeakyReLU()(x) # trying leaky ReLU instead of Activation('relu')(x)

    # Upsampling Layer 2 + Conv2D Layer2
    x = UpSampling2D()(x)
    x = Conv2D(filters=128, kernel_size=5, padding='same', name='Generator_Conv_Layer_2')(x)


    # Batch Norm Layer 3
    x = BatchNormalization(momentum = 0.9)(x)

    # Activation Layer 3
    x = LeakyReLU()(x) # trying leaky ReLU instead of Activation('relu')(x)

    # Upsampling Layer 3 + Conv2D Layer3
    x = UpSampling2D()(x)
    x = Conv2D(filters=64, kernel_size=5, padding='same', name='Generator_Conv_Layer_3')(x)


    # Batch Norm Layer 4
    x = BatchNormalization(momentum = 0.9)(x)

    # Activation Layer 4
    x = LeakyReLU()(x) # trying leaky ReLU instead of Activation('relu')(x)

    # Upsampling Layer 4 + Conv2D Layer4
    x = UpSampling2D()(x)
    x = Conv2D(filters=64, kernel_size=5, padding='same', name='Generator_Conv_Layer_4')(x)


    # Batch Norm Layer 5
    x = BatchNormalization(momentum = 0.9)(x)

    # Activation Layer 5
    x = LeakyReLU()(x) # trying leaky ReLU instead of Activation('relu')(x)



    # Upsampling Layer 5 + Conv2D Layer5
    x = UpSampling2D()(x)
    x = Conv2D(filters=32, kernel_size=5, padding='same', name='Generator_Conv_Layer_5')(x)


    # Batch Norm Layer 6
    x = BatchNormalization(momentum = 0.9)(x)

    # Activation Layer 6
    x = LeakyReLU()(x) # trying leaky ReLU instead of Activation('relu')(x)

    # REMOVED FOR 512x512 PICS
    # ---------------------------
    # Upsampling Layer 7 + Conv2D Layer7
    x = UpSampling2D()(x)
    x = Conv2D(filters=32, kernel_size=5, padding='same', name='Generator_Conv_Layer_6')(x)


    # Batch Norm Layer 7
    x = BatchNormalization(momentum = 0.9)(x)

    # Activation Layer 7
    x = LeakyReLU()(x) # trying leaky ReLU instead of Activation('relu')(x)


    # Upsampling Layer 8 + Conv2D Layer8
    x = Conv2D(filters=3, kernel_size=5, padding='same', name='Generator_Conv_Layer_7')(x)
    # ---------------------------/
    
    # tanh activation layer to scale values to [-1:1]
    x = Activation('tanh')(x)

    # Output - !!!RESCALING ADDED!!! Rescale Values back to [0:255] since the discriminator will automatically rescale back down to [-1:1] as part of the pre-processing pipeline
    g_output = 255 / 2 * (x + 1)


    # Generator Model initialization
    generator = Model(g_input, g_output, name='Generator')
    
    
    return generator

# %% [markdown]
# ### GAN (Full) Model Compilation

# %%
# Definition of KERAS strategy for distributed training (single host, multi GPU strategy = Mirrored). See: https://keras.io/guides/distributed_training/
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():

   
    discriminator = discriminator_model()
    generator = generator_model()
        
    
    # COMPILATION
    discriminator.compile(optimizer=Adam(lr=0.0008), # per Foster, 2017 RMSprop(lr=0.0008)
                          loss=binary_crossentropy,
                          metrics=['accuracy']) 

    # to train the generator as part of the full GAN, we have to freeze the discriminator weights
    discriminator.trainable = False

    model_input = Input(shape=(100), name='GAN_input')
    # Output of generator is connected to the discriminator here
    model_output = discriminator(generator(model_input))

    # The complete GAN model
    gan = Model(model_input, model_output)

    gan.compile(optimizer=RMSprop(lr=0.0004), # here we try RMSprop instead of ADAM with a learning rate of 0.0004 (< than discriminator lr as the discriminator should be stronger than the generator)
                loss=binary_crossentropy, 
                metrics=['accuracy'])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).

# %%
generator.summary()
discriminator.summary()
# Out:
# Model: "Generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Generator_Input (InputLayer) [(None, 100)]             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8192)              819200
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8192)              32768
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 8192)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 32)        0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# Generator_Conv_Layer_1 (Conv (None, 32, 32, 64)        51264
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# Generator_Conv_Layer_2 (Conv (None, 64, 64, 128)       204928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 128, 128)     0
# _________________________________________________________________
# Generator_Conv_Layer_3 (Conv (None, 128, 128, 64)      204864
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128, 128, 64)      0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 256, 256, 64)      0
# _________________________________________________________________
# Generator_Conv_Layer_4 (Conv (None, 256, 256, 64)      102464
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256, 256, 64)      256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 256, 256, 64)      0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 512, 512, 64)      0
# _________________________________________________________________
# Generator_Conv_Layer_5 (Conv (None, 512, 512, 32)      51232
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512, 512, 32)      128
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 512, 512, 32)      0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 1024, 1024, 32)    0
# _________________________________________________________________
# Generator_Conv_Layer_6 (Conv (None, 1024, 1024, 32)    25632
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 1024, 1024, 32)    128
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 1024, 1024, 32)    0
# _________________________________________________________________
# Generator_Conv_Layer_7 (Conv (None, 1024, 1024, 3)     2403
# _________________________________________________________________
# activation (Activation)      (None, 1024, 1024, 3)     0
# _________________________________________________________________
# tf_op_layer_AddV2 (TensorFlo multiple                  0
# _________________________________________________________________
# tf_op_layer_Mul (TensorFlowO multiple                  0
# =================================================================
# Total params: 1,496,291
# Trainable params: 1,479,139
# Non-trainable params: 17,152
# _________________________________________________________________
# Model: "Discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Discriminator_Input (InputLa [(None, None, None, 3)]   0
# _________________________________________________________________
# Preprocessing_Resize (Resizi (None, 512, 512, 3)       0
# _________________________________________________________________
# Preprocessing_Rescale (Resca (None, 512, 512, 3)       0
# _________________________________________________________________
# Discriminator_Conv2D_Layer_1 (None, 256, 256, 128)     9728
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 256, 128)     512
# _________________________________________________________________
# Activation_1 (LeakyReLU)     (None, 256, 256, 128)     0
# _________________________________________________________________
# dropout (Dropout)            (None, 256, 256, 128)     0
# _________________________________________________________________
# Discriminator_Conv2D_Layer_2 (None, 128, 128, 128)     409728
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 128)     512
# _________________________________________________________________
# Activation_2 (LeakyReLU)     (None, 128, 128, 128)     0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128, 128, 128)     0
# _________________________________________________________________
# Discriminator_Conv2D_Layer_3 (None, 64, 64, 128)       409728
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# Activation_3 (LeakyReLU)     (None, 64, 64, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 64, 128)       0
# _________________________________________________________________
# Discriminator_Conv2D_Layer_4 (None, 32, 32, 128)       409728
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# Activation_4 (LeakyReLU)     (None, 32, 32, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32, 32, 128)       0
# _________________________________________________________________
# Discriminator_Conv2D_Layer_5 (None, 16, 16, 64)        204864
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# Activation_5 (LeakyReLU)     (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 16385
# =================================================================
# Total params: 1,462,465
# Trainable params: 0
# Non-trainable params: 1,462,465
# _________________________________________________________________

# %% [markdown]
# ### Training Definition

# %%
if pathlib.Path(f'/data/output/images/{model_name}/').exists():
    print(f'/data/output/images/{model_name} exists')
else:
    print('does not exists')
# Out:
# does not exists

# %%
def train_discriminator(x_train, batch_size, step, tensorboard):
    '''
    Train Discriminator on real and fake images
    '''
    tensorboard.set_model(discriminator)
    
    #make sure discriminator is trainable
    discriminator.trainable = True
    
    #iterate over pre-made batches
    for images, labels in x_train.take(1):
        #Real Images
        labels += 0.05 * tf.random.uniform(labels.shape) #IMPORTANT TRICK: introduce slight randomness to labels to prevent GAN from getting stuck in training
        discriminator.train_on_batch(images, labels)

        #Generated Images
        noise = np.random.normal(0, 1, (batch_size, 100))
        gen_imgs = generator.predict(noise) # random generated images of (untrained) generator
        labels = np.zeros((batch_size, 1))
        labels += 0.05 * tf.random.uniform(labels.shape) #IMPORTANT TRICK: introduce slight randomness to labels to prevent GAN from getting stuck in training
        history = discriminator.train_on_batch(gen_imgs, labels) 
        
    #write out to tensorboard after 1 epoch
    batch_id = step
    tensorboard.on_epoch_end(batch_id, named_logs(discriminator, history))
    
    
def train_generator(batch_size, step, tensorboard):
    '''
    Train Generator on random generated 100 dimensional input vector
    '''
    tensorboard.set_model(gan)
    
    #make sure the discriminator is NOT trainable for the generator/full GAN training
    discriminator.trainable = False
    
    #train generator/GAN
    noise = np.random.normal(0, 1, (batch_size, 100))
    history = gan.train_on_batch(noise, np.zeros((batch_size,1)))
    
    #write out to tensorboard
    batch_id = step
    tensorboard.on_epoch_end(batch_id, named_logs(gan, history))
    
    
def train_gan(disc_train, epoches, batch_size, interval):
    '''
    Train the complete GAN by iterating over the number of epoches
    and alternate between training the discriminator and generator
    '''

    # Tensorboard config
    now = datetime.datetime.now().strftime('%Y-%m-%d_%H%M%S')

    tensorboard = tf.keras.callbacks.TensorBoard(
        log_dir = f'{tboard_dir}/{model_name}_{now}', 
        write_graph = True,
        write_images = True,
        histogram_freq = 1)        
    

    for i in range(epoches):
        print(f"[{10*'-'}] GAN Epoch {i+1} started [{10*'-'}]")

        # !!! Add another for loop here over step, image in enumerate(dataset) see https://www.tensorflow.org/guide/keras/writing_a_training_loop_from_scratch  (at the bottom, last code block)
        train_discriminator(disc_train, batch_size, i, tensorboard)
        train_generator(batch_size, i, tensorboard)
        
        # for defined interval take snapshots of generator output and save model
        if (i+1) % interval == 0:
            # take sample output images from generator
            sample_img(i)

            # save corresponding model
            if pathlib.Path(f'{out_model_dir}/{model_name}').exists():
                gan.save(f'{out_model_dir}/{model_name}/full-gan-{now}.h5')
                discriminator.save(f'{out_model_dir}/{model_name}/discriminator-{now}.h5') 
                generator.save(f'{out_model_dir}/{model_name}/generator-{now}.h5')        
            else:
                #make dir
                os.mkdir(f'{out_model_dir}/{model_name}')
                #write
                gan.save(f'{out_model_dir}/{model_name}/full-gan-{now}.h5')
                discriminator.save(f'{out_model_dir}/{model_name}/discriminator-{now}.h5') 
                generator.save(f'{out_model_dir}/{model_name}/generator-{now}.h5') 
            
# Transform train_on_batch return value
# to dict expected by on_batch_end callback
def named_logs(model, logs):
    result = {}
    for l in zip(model.metrics_names, logs):
        result[l[0]] = l[1]
    return result
        
   
     
# ---------------> CHECK IMPLEMENTATION <-------------------        
def sample_img(epoch):
    noise = np.random.normal(0, 1, (10, 100))
    gen_imgs = generator.predict(noise)
    
    gen_imgs = gen_imgs.reshape((10, 1024, 1024, 3))
    
    # save 10 example images
    for i in range(10):
        fig = plt.figure(figsize=(20, 20))
        plt.imshow(gen_imgs[i])
        plt.title(f'Example Generator Output')
        plt.axis('off')
        
        # adjust path based on whether execution is local or on linux VM
        if pathlib.Path(f'/data/output/images/{model_name}').exists():
            fig.savefig(f'/data/output/images/{model_name}/sample_image_epoch{epoch+1}-{i+1}.png')
            plt.close()
        else:
            #mkdir
            os.mkdir(f'/data/output/images/{model_name}')
            #save
            fig.savefig(f'/data/output/images/{model_name}/sample_image_epoch{epoch+1}-{i+1}.png')
            plt.close()

# %% [markdown]
# ### Training (over x Epochs)

# %%
# Train GAN
train_gan(train_ds, 2000, BATCH_SIZE, checkpoint)
# Out:
# [----------] GAN Epoch 1 started [----------]
# [----------] GAN Epoch 2 started [----------]
# [----------] GAN Epoch 3 started [----------]
# [----------] GAN Epoch 4 started [----------]
# [----------] GAN Epoch 5 started [----------]
# [----------] GAN Epoch 6 started [----------]
# [----------] GAN Epoch 7 started [----------]
# [----------] GAN Epoch 8 started [----------]
# [----------] GAN Epoch 9 started [----------]
# [----------] GAN Epoch 10 started [----------]
# [----------] GAN Epoch 11 started [----------]
# [----------] GAN Epoch 12 started [----------]
# [----------] GAN Epoch 13 started [----------]
# [----------] GAN Epoch 14 started [----------]
# [----------] GAN Epoch 15 started [----------]
# [----------] GAN Epoch 16 started [----------]
# [----------] GAN Epoch 17 started [----------]
# [----------] GAN Epoch 18 started [----------]
# [----------] GAN Epoch 19 started [----------]
# [----------] GAN Epoch 20 started [----------]
# [----------] GAN Epoch 21 started [----------]
# [----------] GAN Epoch 22 started [----------]
# [----------] GAN Epoch 23 started [----------]
# [----------] GAN Epoch 24 started [----------]
# [----------] GAN Epoch 25 started [----------]
# [----------] GAN Epoch 26 started [----------]
# [----------] GAN Epoch 27 started [----------]
# [----------] GAN Epoch 28 started [----------]
# [----------] GAN Epoch 29 started [----------]
# [----------] GAN Epoch 30 started [----------]
# [----------] GAN Epoch 31 started [----------]
# [----------] GAN Epoch 32 started [----------]
# [----------] GAN Epoch 33 started [----------]
# [----------] GAN Epoch 34 started [----------]
# [----------] GAN Epoch 35 started [----------]
# [----------] GAN Epoch 36 started [----------]
# [----------] GAN Epoch 37 started [----------]
# [----------] GAN Epoch 38 started [----------]
# [----------] GAN Epoch 39 started [----------]
# [----------] GAN Epoch 40 started [----------]
# [----------] GAN Epoch 41 started [----------]
# [----------] GAN Epoch 42 started [----------]
# [----------] GAN Epoch 43 started [----------]
# [----------] GAN Epoch 44 started [----------]
# [----------] GAN Epoch 45 started [----------]
# [----------] GAN Epoch 46 started [----------]
# [----------] GAN Epoch 47 started [----------]
# [----------] GAN Epoch 48 started [----------]
# [----------] GAN Epoch 49 started [----------]
# [----------] GAN Epoch 50 started [----------]
# [----------] GAN Epoch 51 started [----------]
# [----------] GAN Epoch 124 started [----------]
# [----------] GAN Epoch 125 started [----------]
# [----------] GAN Epoch 126 started [----------]
# [----------] GAN Epoch 127 started [----------]
# [----------] GAN Epoch 128 started [----------]
# [----------] GAN Epoch 129 started [----------]
# [----------] GAN Epoch 130 started [----------]
# [----------] GAN Epoch 131 started [----------]
# [----------] GAN Epoch 132 started [----------]
# [----------] GAN Epoch 133 started [----------]
# [----------] GAN Epoch 134 started [----------]
# [----------] GAN Epoch 135 started [----------]
# [----------] GAN Epoch 136 started [----------]
# [----------] GAN Epoch 137 started [----------]
# [----------] GAN Epoch 138 started [----------]
# [----------] GAN Epoch 139 started [----------]
# [----------] GAN Epoch 140 started [----------]
# [----------] GAN Epoch 141 started [----------]
# [----------] GAN Epoch 142 started [----------]
# [----------] GAN Epoch 143 started [----------]
# [----------] GAN Epoch 144 started [----------]
# [----------] GAN Epoch 145 started [----------]
# [----------] GAN Epoch 146 started [----------]
# [----------] GAN Epoch 147 started [----------]
# [----------] GAN Epoch 148 started [----------]
# [----------] GAN Epoch 149 started [----------]
# [----------] GAN Epoch 150 started [----------]
# [----------] GAN Epoch 151 started [----------]
# [----------] GAN Epoch 152 started [----------]
# [----------] GAN Epoch 153 started [----------]
# [----------] GAN Epoch 154 started [----------]
# [----------] GAN Epoch 155 started [----------]
# [----------] GAN Epoch 156 started [----------]
# [----------] GAN Epoch 157 started [----------]
# [----------] GAN Epoch 158 started [----------]
# [----------] GAN Epoch 159 started [----------]
# [----------] GAN Epoch 160 started [----------]
# [----------] GAN Epoch 161 started [----------]
# [----------] GAN Epoch 162 started [----------]
# [----------] GAN Epoch 163 started [----------]
# [----------] GAN Epoch 164 started [----------]
# [----------] GAN Epoch 165 started [----------]
# [----------] GAN Epoch 166 started [----------]
# [----------] GAN Epoch 167 started [----------]
# [----------] GAN Epoch 168 started [----------]
# [----------] GAN Epoch 169 started [----------]
# [----------] GAN Epoch 170 started [----------]
# [----------] GAN Epoch 171 started [----------]
# [----------] GAN Epoch 172 started [----------]
# [----------] GAN Epoch 173 started [----------]
# [----------] GAN Epoch 174 started [----------]
# [----------] GAN Epoch 175 started [----------]
# [----------] GAN Epoch 176 started [----------]
# [----------] GAN Epoch 177 started [----------]
# [----------] GAN Epoch 178 started [----------]
# [----------] GAN Epoch 179 started [----------]
# [----------] GAN Epoch 180 started [----------]
# [----------] GAN Epoch 181 started [----------]
# [----------] GAN Epoch 182 started [----------]
# [----------] GAN Epoch 183 started [----------]
# [----------] GAN Epoch 184 started [----------]
# [----------] GAN Epoch 185 started [----------]
# [----------] GAN Epoch 186 started [----------]
# [----------] GAN Epoch 187 started [----------]
# [----------] GAN Epoch 188 started [----------]
# [----------] GAN Epoch 189 started [----------]
# [----------] GAN Epoch 190 started [----------]
# [----------] GAN Epoch 191 started [----------]
# [----------] GAN Epoch 192 started [----------]
# [----------] GAN Epoch 193 started [----------]
# [----------] GAN Epoch 194 started [----------]
# [----------] GAN Epoch 195 started [----------]
# [----------] GAN Epoch 196 started [----------]
# [----------] GAN Epoch 343 started [----------]
# [----------] GAN Epoch 344 started [----------]
# [----------] GAN Epoch 345 started [----------]
# [----------] GAN Epoch 346 started [----------]
# [----------] GAN Epoch 347 started [----------]
# [----------] GAN Epoch 348 started [----------]
# [----------] GAN Epoch 349 started [----------]
# [----------] GAN Epoch 350 started [----------]
# [----------] GAN Epoch 351 started [----------]
# [----------] GAN Epoch 352 started [----------]
# [----------] GAN Epoch 353 started [----------]
# [----------] GAN Epoch 354 started [----------]
# [----------] GAN Epoch 355 started [----------]
# [----------] GAN Epoch 356 started [----------]
# [----------] GAN Epoch 357 started [----------]
# [----------] GAN Epoch 358 started [----------]
# [----------] GAN Epoch 359 started [----------]
# [----------] GAN Epoch 360 started [----------]
# [----------] GAN Epoch 361 started [----------]
# [----------] GAN Epoch 362 started [----------]
# [----------] GAN Epoch 363 started [----------]
# [----------] GAN Epoch 364 started [----------]
# [----------] GAN Epoch 365 started [----------]
# [----------] GAN Epoch 366 started [----------]
# [----------] GAN Epoch 367 started [----------]
# [----------] GAN Epoch 368 started [----------]
# [----------] GAN Epoch 369 started [----------]
# [----------] GAN Epoch 370 started [----------]
# [----------] GAN Epoch 371 started [----------]
# [----------] GAN Epoch 372 started [----------]
# [----------] GAN Epoch 373 started [----------]
# [----------] GAN Epoch 374 started [----------]
# [----------] GAN Epoch 375 started [----------]
# [----------] GAN Epoch 376 started [----------]
# [----------] GAN Epoch 377 started [----------]
# [----------] GAN Epoch 378 started [----------]
# [----------] GAN Epoch 379 started [----------]
# [----------] GAN Epoch 380 started [----------]
# [----------] GAN Epoch 381 started [----------]
# [----------] GAN Epoch 382 started [----------]
# [----------] GAN Epoch 383 started [----------]
# [----------] GAN Epoch 384 started [----------]
# [----------] GAN Epoch 385 started [----------]
# [----------] GAN Epoch 386 started [----------]
# [----------] GAN Epoch 387 started [----------]
# [----------] GAN Epoch 388 started [----------]
# [----------] GAN Epoch 389 started [----------]
# [----------] GAN Epoch 390 started [----------]
# [----------] GAN Epoch 391 started [----------]
# [----------] GAN Epoch 392 started [----------]
# [----------] GAN Epoch 393 started [----------]
# [----------] GAN Epoch 394 started [----------]
# [----------] GAN Epoch 395 started [----------]
# [----------] GAN Epoch 396 started [----------]
# [----------] GAN Epoch 397 started [----------]
# [----------] GAN Epoch 398 started [----------]
# [----------] GAN Epoch 399 started [----------]
# [----------] GAN Epoch 400 started [----------]
# [----------] GAN Epoch 401 started [----------]
# [----------] GAN Epoch 402 started [----------]
# [----------] GAN Epoch 403 started [----------]
# [----------] GAN Epoch 404 started [----------]
# [----------] GAN Epoch 405 started [----------]
# [----------] GAN Epoch 406 started [----------]
# [----------] GAN Epoch 407 started [----------]
# [----------] GAN Epoch 408 started [----------]
# [----------] GAN Epoch 409 started [----------]
# [----------] GAN Epoch 410 started [----------]
# [----------] GAN Epoch 411 started [----------]
# [----------] GAN Epoch 412 started [----------]
# [----------] GAN Epoch 413 started [----------]
# [----------] GAN Epoch 414 started [----------]
# [----------] GAN Epoch 415 started [----------]
# [----------] GAN Epoch 489 started [----------]
# [----------] GAN Epoch 490 started [----------]
# [----------] GAN Epoch 491 started [----------]
# [----------] GAN Epoch 492 started [----------]
# [----------] GAN Epoch 493 started [----------]
# [----------] GAN Epoch 494 started [----------]
# [----------] GAN Epoch 495 started [----------]
# [----------] GAN Epoch 496 started [----------]
# [----------] GAN Epoch 497 started [----------]
# [----------] GAN Epoch 498 started [----------]
# [----------] GAN Epoch 499 started [----------]
# [----------] GAN Epoch 500 started [----------]
# [----------] GAN Epoch 501 started [----------]
# [----------] GAN Epoch 502 started [----------]
# [----------] GAN Epoch 503 started [----------]
# [----------] GAN Epoch 504 started [----------]
# [----------] GAN Epoch 505 started [----------]
# [----------] GAN Epoch 506 started [----------]
# [----------] GAN Epoch 507 started [----------]
# [----------] GAN Epoch 508 started [----------]
# [----------] GAN Epoch 509 started [----------]
# [----------] GAN Epoch 510 started [----------]
# [----------] GAN Epoch 511 started [----------]
# [----------] GAN Epoch 512 started [----------]
# [----------] GAN Epoch 513 started [----------]
# [----------] GAN Epoch 514 started [----------]
# [----------] GAN Epoch 515 started [----------]
# [----------] GAN Epoch 516 started [----------]
# [----------] GAN Epoch 517 started [----------]
# [----------] GAN Epoch 518 started [----------]
# [----------] GAN Epoch 519 started [----------]
# [----------] GAN Epoch 520 started [----------]
# [----------] GAN Epoch 521 started [----------]
# [----------] GAN Epoch 522 started [----------]
# [----------] GAN Epoch 523 started [----------]
# [----------] GAN Epoch 524 started [----------]
# [----------] GAN Epoch 525 started [----------]
# [----------] GAN Epoch 526 started [----------]
# [----------] GAN Epoch 527 started [----------]
# [----------] GAN Epoch 528 started [----------]
# [----------] GAN Epoch 529 started [----------]
# [----------] GAN Epoch 530 started [----------]
# [----------] GAN Epoch 531 started [----------]
# [----------] GAN Epoch 532 started [----------]
# [----------] GAN Epoch 533 started [----------]
# [----------] GAN Epoch 534 started [----------]
# [----------] GAN Epoch 535 started [----------]
# [----------] GAN Epoch 536 started [----------]
# [----------] GAN Epoch 537 started [----------]
# [----------] GAN Epoch 538 started [----------]
# [----------] GAN Epoch 539 started [----------]
# [----------] GAN Epoch 540 started [----------]
# [----------] GAN Epoch 541 started [----------]
# [----------] GAN Epoch 542 started [----------]
# [----------] GAN Epoch 543 started [----------]
# [----------] GAN Epoch 544 started [----------]
# [----------] GAN Epoch 545 started [----------]
# [----------] GAN Epoch 546 started [----------]
# [----------] GAN Epoch 547 started [----------]
# [----------] GAN Epoch 548 started [----------]
# [----------] GAN Epoch 549 started [----------]
# [----------] GAN Epoch 550 started [----------]
# [----------] GAN Epoch 551 started [----------]
# [----------] GAN Epoch 552 started [----------]
# [----------] GAN Epoch 553 started [----------]
# [----------] GAN Epoch 554 started [----------]
# [----------] GAN Epoch 555 started [----------]
# [----------] GAN Epoch 556 started [----------]
# [----------] GAN Epoch 557 started [----------]
# [----------] GAN Epoch 558 started [----------]
# [----------] GAN Epoch 559 started [----------]
# [----------] GAN Epoch 560 started [----------]
# [----------] GAN Epoch 634 started [----------]
# [----------] GAN Epoch 635 started [----------]
# [----------] GAN Epoch 636 started [----------]
# [----------] GAN Epoch 637 started [----------]
# [----------] GAN Epoch 638 started [----------]
# [----------] GAN Epoch 639 started [----------]
# [----------] GAN Epoch 640 started [----------]
# [----------] GAN Epoch 641 started [----------]
# [----------] GAN Epoch 642 started [----------]
# [----------] GAN Epoch 643 started [----------]
# [----------] GAN Epoch 644 started [----------]
# [----------] GAN Epoch 645 started [----------]
# [----------] GAN Epoch 646 started [----------]
# [----------] GAN Epoch 647 started [----------]
# [----------] GAN Epoch 648 started [----------]
# [----------] GAN Epoch 649 started [----------]
# [----------] GAN Epoch 650 started [----------]
# [----------] GAN Epoch 651 started [----------]
# [----------] GAN Epoch 652 started [----------]
# [----------] GAN Epoch 653 started [----------]
# [----------] GAN Epoch 654 started [----------]
# [----------] GAN Epoch 655 started [----------]
# [----------] GAN Epoch 656 started [----------]
# [----------] GAN Epoch 657 started [----------]
# [----------] GAN Epoch 658 started [----------]
# [----------] GAN Epoch 659 started [----------]
# [----------] GAN Epoch 660 started [----------]
# [----------] GAN Epoch 661 started [----------]
# [----------] GAN Epoch 662 started [----------]
# [----------] GAN Epoch 663 started [----------]
# [----------] GAN Epoch 664 started [----------]
# [----------] GAN Epoch 665 started [----------]
# [----------] GAN Epoch 666 started [----------]
# [----------] GAN Epoch 667 started [----------]
# [----------] GAN Epoch 668 started [----------]
# [----------] GAN Epoch 669 started [----------]
# [----------] GAN Epoch 670 started [----------]
# [----------] GAN Epoch 671 started [----------]
# [----------] GAN Epoch 672 started [----------]
# [----------] GAN Epoch 673 started [----------]
# [----------] GAN Epoch 674 started [----------]
# [----------] GAN Epoch 675 started [----------]
# [----------] GAN Epoch 676 started [----------]
# [----------] GAN Epoch 677 started [----------]
# [----------] GAN Epoch 678 started [----------]
# [----------] GAN Epoch 679 started [----------]
# [----------] GAN Epoch 680 started [----------]
# [----------] GAN Epoch 681 started [----------]
# [----------] GAN Epoch 682 started [----------]
# [----------] GAN Epoch 683 started [----------]
# [----------] GAN Epoch 684 started [----------]
# [----------] GAN Epoch 685 started [----------]
# [----------] GAN Epoch 686 started [----------]
# [----------] GAN Epoch 687 started [----------]
# [----------] GAN Epoch 688 started [----------]
# [----------] GAN Epoch 689 started [----------]
# [----------] GAN Epoch 690 started [----------]
# [----------] GAN Epoch 691 started [----------]
# [----------] GAN Epoch 692 started [----------]
# [----------] GAN Epoch 693 started [----------]
# [----------] GAN Epoch 694 started [----------]
# [----------] GAN Epoch 695 started [----------]
# [----------] GAN Epoch 696 started [----------]
# [----------] GAN Epoch 697 started [----------]
# [----------] GAN Epoch 698 started [----------]
# [----------] GAN Epoch 699 started [----------]
# [----------] GAN Epoch 700 started [----------]
# [----------] GAN Epoch 701 started [----------]
# [----------] GAN Epoch 702 started [----------]
# [----------] GAN Epoch 703 started [----------]
# [----------] GAN Epoch 704 started [----------]
# [----------] GAN Epoch 705 started [----------]
# [----------] GAN Epoch 706 started [----------]
# [----------] GAN Epoch 707 started [----------]
# [----------] GAN Epoch 708 started [----------]
# [----------] GAN Epoch 709 started [----------]
# [----------] GAN Epoch 710 started [----------]
# [----------] GAN Epoch 711 started [----------]
# [----------] GAN Epoch 712 started [----------]
# [----------] GAN Epoch 713 started [----------]
# [----------] GAN Epoch 714 started [----------]
# [----------] GAN Epoch 715 started [----------]
# [----------] GAN Epoch 716 started [----------]
# [----------] GAN Epoch 717 started [----------]
# [----------] GAN Epoch 718 started [----------]
# [----------] GAN Epoch 719 started [----------]
# [----------] GAN Epoch 720 started [----------]
# [----------] GAN Epoch 721 started [----------]
# [----------] GAN Epoch 722 started [----------]
# [----------] GAN Epoch 723 started [----------]
# [----------] GAN Epoch 724 started [----------]
# [----------] GAN Epoch 725 started [----------]
# [----------] GAN Epoch 726 started [----------]
# [----------] GAN Epoch 727 started [----------]
# [----------] GAN Epoch 728 started [----------]
# [----------] GAN Epoch 729 started [----------]
# [----------] GAN Epoch 730 started [----------]
# [----------] GAN Epoch 731 started [----------]
# [----------] GAN Epoch 732 started [----------]
# [----------] GAN Epoch 733 started [----------]
# [----------] GAN Epoch 734 started [----------]
# [----------] GAN Epoch 735 started [----------]
# [----------] GAN Epoch 736 started [----------]
# [----------] GAN Epoch 737 started [----------]
# [----------] GAN Epoch 738 started [----------]
# [----------] GAN Epoch 739 started [----------]
# [----------] GAN Epoch 740 started [----------]
# [----------] GAN Epoch 741 started [----------]
# [----------] GAN Epoch 742 started [----------]
# [----------] GAN Epoch 743 started [----------]
# [----------] GAN Epoch 744 started [----------]
# [----------] GAN Epoch 745 started [----------]
# [----------] GAN Epoch 746 started [----------]
# [----------] GAN Epoch 747 started [----------]
# [----------] GAN Epoch 748 started [----------]
# [----------] GAN Epoch 749 started [----------]
# [----------] GAN Epoch 750 started [----------]
# [----------] GAN Epoch 751 started [----------]
# [----------] GAN Epoch 752 started [----------]
# [----------] GAN Epoch 753 started [----------]
# [----------] GAN Epoch 754 started [----------]
# [----------] GAN Epoch 755 started [----------]
# [----------] GAN Epoch 756 started [----------]
# [----------] GAN Epoch 757 started [----------]
# [----------] GAN Epoch 758 started [----------]
# [----------] GAN Epoch 759 started [----------]
# [----------] GAN Epoch 760 started [----------]
# [----------] GAN Epoch 761 started [----------]
# [----------] GAN Epoch 762 started [----------]
# [----------] GAN Epoch 763 started [----------]
# [----------] GAN Epoch 764 started [----------]
# [----------] GAN Epoch 765 started [----------]
# [----------] GAN Epoch 766 started [----------]
# [----------] GAN Epoch 767 started [----------]
# [----------] GAN Epoch 768 started [----------]
# [----------] GAN Epoch 769 started [----------]
# [----------] GAN Epoch 770 started [----------]
# [----------] GAN Epoch 771 started [----------]
# [----------] GAN Epoch 772 started [----------]
# [----------] GAN Epoch 773 started [----------]
# [----------] GAN Epoch 774 started [----------]
# [----------] GAN Epoch 775 started [----------]
# [----------] GAN Epoch 776 started [----------]
# [----------] GAN Epoch 777 started [----------]
# [----------] GAN Epoch 778 started [----------]
# [----------] GAN Epoch 779 started [----------]
# [----------] GAN Epoch 780 started [----------]
# [----------] GAN Epoch 781 started [----------]
# [----------] GAN Epoch 782 started [----------]
# [----------] GAN Epoch 783 started [----------]
# [----------] GAN Epoch 784 started [----------]
# [----------] GAN Epoch 785 started [----------]
# [----------] GAN Epoch 786 started [----------]
# [----------] GAN Epoch 787 started [----------]
# [----------] GAN Epoch 788 started [----------]
# [----------] GAN Epoch 789 started [----------]
# [----------] GAN Epoch 790 started [----------]
# [----------] GAN Epoch 791 started [----------]
# [----------] GAN Epoch 792 started [----------]
# [----------] GAN Epoch 793 started [----------]
# [----------] GAN Epoch 794 started [----------]
# [----------] GAN Epoch 795 started [----------]
# [----------] GAN Epoch 796 started [----------]
# [----------] GAN Epoch 797 started [----------]
# [----------] GAN Epoch 798 started [----------]
# [----------] GAN Epoch 799 started [----------]
# [----------] GAN Epoch 800 started [----------]
# [----------] GAN Epoch 801 started [----------]
# [----------] GAN Epoch 802 started [----------]
# [----------] GAN Epoch 803 started [----------]
# [----------] GAN Epoch 804 started [----------]
# [----------] GAN Epoch 805 started [----------]
# [----------] GAN Epoch 806 started [----------]
# [----------] GAN Epoch 807 started [----------]
# [----------] GAN Epoch 808 started [----------]
# [----------] GAN Epoch 809 started [----------]
# [----------] GAN Epoch 810 started [----------]
# [----------] GAN Epoch 811 started [----------]
# [----------] GAN Epoch 812 started [----------]
# [----------] GAN Epoch 813 started [----------]
# [----------] GAN Epoch 814 started [----------]
# [----------] GAN Epoch 815 started [----------]
# [----------] GAN Epoch 816 started [----------]
# [----------] GAN Epoch 817 started [----------]
# [----------] GAN Epoch 818 started [----------]
# [----------] GAN Epoch 819 started [----------]
# [----------] GAN Epoch 820 started [----------]
# [----------] GAN Epoch 821 started [----------]
# [----------] GAN Epoch 822 started [----------]
# [----------] GAN Epoch 823 started [----------]
# [----------] GAN Epoch 824 started [----------]
# [----------] GAN Epoch 825 started [----------]
# [----------] GAN Epoch 826 started [----------]
# [----------] GAN Epoch 827 started [----------]
# [----------] GAN Epoch 828 started [----------]
# [----------] GAN Epoch 829 started [----------]
# [----------] GAN Epoch 830 started [----------]
# [----------] GAN Epoch 831 started [----------]
# [----------] GAN Epoch 832 started [----------]
# [----------] GAN Epoch 833 started [----------]
# [----------] GAN Epoch 834 started [----------]
# [----------] GAN Epoch 835 started [----------]
# [----------] GAN Epoch 836 started [----------]
# [----------] GAN Epoch 837 started [----------]
# [----------] GAN Epoch 838 started [----------]
# [----------] GAN Epoch 839 started [----------]
# [----------] GAN Epoch 840 started [----------]
# [----------] GAN Epoch 841 started [----------]
# [----------] GAN Epoch 842 started [----------]
# [----------] GAN Epoch 843 started [----------]
# [----------] GAN Epoch 844 started [----------]
# [----------] GAN Epoch 845 started [----------]
# [----------] GAN Epoch 846 started [----------]
# [----------] GAN Epoch 847 started [----------]
# [----------] GAN Epoch 848 started [----------]
# [----------] GAN Epoch 849 started [----------]
# [----------] GAN Epoch 850 started [----------]
# [----------] GAN Epoch 851 started [----------]
# [----------] GAN Epoch 852 started [----------]
# [----------] GAN Epoch 853 started [----------]
# [----------] GAN Epoch 854 started [----------]
# [----------] GAN Epoch 855 started [----------]
# [----------] GAN Epoch 856 started [----------]
# [----------] GAN Epoch 857 started [----------]
# [----------] GAN Epoch 858 started [----------]
# [----------] GAN Epoch 859 started [----------]
# [----------] GAN Epoch 860 started [----------]
# [----------] GAN Epoch 861 started [----------]
# [----------] GAN Epoch 862 started [----------]
# [----------] GAN Epoch 863 started [----------]
# [----------] GAN Epoch 864 started [----------]
# [----------] GAN Epoch 865 started [----------]
# [----------] GAN Epoch 866 started [----------]
# [----------] GAN Epoch 867 started [----------]
# [----------] GAN Epoch 868 started [----------]
# [----------] GAN Epoch 869 started [----------]
# [----------] GAN Epoch 870 started [----------]
# [----------] GAN Epoch 871 started [----------]
# [----------] GAN Epoch 872 started [----------]
# [----------] GAN Epoch 873 started [----------]
# [----------] GAN Epoch 874 started [----------]
# [----------] GAN Epoch 875 started [----------]
# [----------] GAN Epoch 876 started [----------]
# [----------] GAN Epoch 877 started [----------]
# [----------] GAN Epoch 878 started [----------]
# [----------] GAN Epoch 879 started [----------]
# [----------] GAN Epoch 880 started [----------]
# [----------] GAN Epoch 881 started [----------]
# [----------] GAN Epoch 882 started [----------]
# [----------] GAN Epoch 883 started [----------]
# [----------] GAN Epoch 884 started [----------]
# [----------] GAN Epoch 885 started [----------]
# [----------] GAN Epoch 886 started [----------]
# [----------] GAN Epoch 887 started [----------]
# [----------] GAN Epoch 888 started [----------]
# [----------] GAN Epoch 889 started [----------]
# [----------] GAN Epoch 890 started [----------]
# [----------] GAN Epoch 891 started [----------]
# [----------] GAN Epoch 892 started [----------]
# [----------] GAN Epoch 893 started [----------]
# [----------] GAN Epoch 894 started [----------]
# [----------] GAN Epoch 895 started [----------]
# [----------] GAN Epoch 896 started [----------]
# [----------] GAN Epoch 897 started [----------]
# [----------] GAN Epoch 898 started [----------]
# [----------] GAN Epoch 899 started [----------]
# [----------] GAN Epoch 900 started [----------]
# [----------] GAN Epoch 901 started [----------]
# [----------] GAN Epoch 902 started [----------]
# [----------] GAN Epoch 903 started [----------]
# [----------] GAN Epoch 904 started [----------]
# [----------] GAN Epoch 905 started [----------]
# [----------] GAN Epoch 906 started [----------]
# [----------] GAN Epoch 907 started [----------]
# [----------] GAN Epoch 908 started [----------]
# [----------] GAN Epoch 909 started [----------]
# [----------] GAN Epoch 910 started [----------]
# [----------] GAN Epoch 911 started [----------]
# [----------] GAN Epoch 912 started [----------]
# [----------] GAN Epoch 913 started [----------]
# [----------] GAN Epoch 914 started [----------]
# [----------] GAN Epoch 915 started [----------]
# [----------] GAN Epoch 916 started [----------]
# [----------] GAN Epoch 917 started [----------]
# [----------] GAN Epoch 918 started [----------]
# [----------] GAN Epoch 919 started [----------]
# [----------] GAN Epoch 920 started [----------]
# [----------] GAN Epoch 921 started [----------]
# [----------] GAN Epoch 922 started [----------]
# [----------] GAN Epoch 923 started [----------]
# [----------] GAN Epoch 924 started [----------]
# [----------] GAN Epoch 925 started [----------]
# [----------] GAN Epoch 926 started [----------]
# [----------] GAN Epoch 927 started [----------]
# [----------] GAN Epoch 928 started [----------]
# [----------] GAN Epoch 929 started [----------]
# [----------] GAN Epoch 930 started [----------]
# [----------] GAN Epoch 931 started [----------]
# [----------] GAN Epoch 932 started [----------]
# [----------] GAN Epoch 933 started [----------]
# [----------] GAN Epoch 934 started [----------]
# [----------] GAN Epoch 935 started [----------]
# [----------] GAN Epoch 936 started [----------]
# [----------] GAN Epoch 937 started [----------]
# [----------] GAN Epoch 938 started [----------]
# [----------] GAN Epoch 939 started [----------]
# [----------] GAN Epoch 940 started [----------]
# [----------] GAN Epoch 941 started [----------]
# [----------] GAN Epoch 942 started [----------]
# [----------] GAN Epoch 943 started [----------]
# [----------] GAN Epoch 944 started [----------]
# [----------] GAN Epoch 945 started [----------]
# [----------] GAN Epoch 946 started [----------]
# [----------] GAN Epoch 947 started [----------]
# [----------] GAN Epoch 948 started [----------]
# [----------] GAN Epoch 949 started [----------]
# [----------] GAN Epoch 950 started [----------]
# [----------] GAN Epoch 951 started [----------]
# [----------] GAN Epoch 952 started [----------]
# [----------] GAN Epoch 953 started [----------]
# [----------] GAN Epoch 954 started [----------]
# [----------] GAN Epoch 955 started [----------]
# [----------] GAN Epoch 956 started [----------]
# [----------] GAN Epoch 957 started [----------]
# [----------] GAN Epoch 958 started [----------]
# [----------] GAN Epoch 959 started [----------]
# [----------] GAN Epoch 960 started [----------]
# [----------] GAN Epoch 961 started [----------]
# [----------] GAN Epoch 962 started [----------]
# [----------] GAN Epoch 963 started [----------]
# [----------] GAN Epoch 964 started [----------]
# [----------] GAN Epoch 965 started [----------]
# [----------] GAN Epoch 966 started [----------]
# [----------] GAN Epoch 967 started [----------]
# [----------] GAN Epoch 968 started [----------]
# [----------] GAN Epoch 969 started [----------]
# [----------] GAN Epoch 970 started [----------]
# [----------] GAN Epoch 971 started [----------]
# [----------] GAN Epoch 972 started [----------]
# [----------] GAN Epoch 973 started [----------]
# [----------] GAN Epoch 974 started [----------]
# [----------] GAN Epoch 975 started [----------]
# [----------] GAN Epoch 976 started [----------]
# [----------] GAN Epoch 977 started [----------]
# [----------] GAN Epoch 978 started [----------]
# [----------] GAN Epoch 979 started [----------]
# [----------] GAN Epoch 980 started [----------]
# [----------] GAN Epoch 981 started [----------]
# [----------] GAN Epoch 982 started [----------]
# [----------] GAN Epoch 983 started [----------]
# [----------] GAN Epoch 984 started [----------]
# [----------] GAN Epoch 985 started [----------]
# [----------] GAN Epoch 986 started [----------]
# [----------] GAN Epoch 987 started [----------]
# [----------] GAN Epoch 988 started [----------]
# [----------] GAN Epoch 989 started [----------]
# [----------] GAN Epoch 990 started [----------]
# [----------] GAN Epoch 991 started [----------]
# [----------] GAN Epoch 992 started [----------]
# [----------] GAN Epoch 993 started [----------]
# [----------] GAN Epoch 994 started [----------]
# [----------] GAN Epoch 995 started [----------]
# [----------] GAN Epoch 996 started [----------]
# [----------] GAN Epoch 997 started [----------]
# [----------] GAN Epoch 1948 started [----------]
# [----------] GAN Epoch 1949 started [----------]
# [----------] GAN Epoch 1950 started [----------]
# [----------] GAN Epoch 1951 started [----------]
# [----------] GAN Epoch 1952 started [----------]
# [----------] GAN Epoch 1953 started [----------]
# [----------] GAN Epoch 1954 started [----------]
# [----------] GAN Epoch 1955 started [----------]
# [----------] GAN Epoch 1956 started [----------]
# [----------] GAN Epoch 1957 started [----------]
# [----------] GAN Epoch 1958 started [----------]
# [----------] GAN Epoch 1959 started [----------]
# [----------] GAN Epoch 1960 started [----------]
# [----------] GAN Epoch 1961 started [----------]
# [----------] GAN Epoch 1962 started [----------]
# [----------] GAN Epoch 1963 started [----------]
# [----------] GAN Epoch 1964 started [----------]
# [----------] GAN Epoch 1965 started [----------]
# [----------] GAN Epoch 1966 started [----------]
# [----------] GAN Epoch 1967 started [----------]
# [----------] GAN Epoch 1968 started [----------]
# [----------] GAN Epoch 1969 started [----------]
# [----------] GAN Epoch 1970 started [----------]
# [----------] GAN Epoch 1971 started [----------]
# [----------] GAN Epoch 1972 started [----------]
# [----------] GAN Epoch 1973 started [----------]
# [----------] GAN Epoch 1974 started [----------]
# [----------] GAN Epoch 1975 started [----------]
# [----------] GAN Epoch 1976 started [----------]
# [----------] GAN Epoch 1977 started [----------]
# [----------] GAN Epoch 1978 started [----------]
# [----------] GAN Epoch 1979 started [----------]
# [----------] GAN Epoch 1980 started [----------]
# [----------] GAN Epoch 1981 started [----------]
# [----------] GAN Epoch 1982 started [----------]
# [----------] GAN Epoch 1983 started [----------]
# [----------] GAN Epoch 1984 started [----------]
# [----------] GAN Epoch 1985 started [----------]
# [----------] GAN Epoch 1986 started [----------]
# [----------] GAN Epoch 1987 started [----------]
# [----------] GAN Epoch 1988 started [----------]
# [----------] GAN Epoch 1989 started [----------]
# [----------] GAN Epoch 1990 started [----------]
# [----------] GAN Epoch 1991 started [----------]
# [----------] GAN Epoch 1992 started [----------]
# [----------] GAN Epoch 1993 started [----------]
# [----------] GAN Epoch 1994 started [----------]
# [----------] GAN Epoch 1995 started [----------]
# [----------] GAN Epoch 1996 started [----------]
# [----------] GAN Epoch 1997 started [----------]
# [----------] GAN Epoch 1998 started [----------]
# [----------] GAN Epoch 1999 started [----------]
# [----------] GAN Epoch 2000 started [----------]

# %% [markdown]
# ### Generate Examples using learned Generator Model

# %%
# load generator

generator.compile(optimizer=Adam(lr=0.0008), # per Foster, 2017 RMSprop(lr=0.0008)
                          loss=binary_crossentropy,
                          metrics=['accuracy'])
generator = tf.keras.models.load_model('/data/output/models/dwarfgan001/generator-2021-03-17_104329.h5')

# generate new example of learned representation in latent space
noise = np.random.normal(0, 1, (1, 100))
res = generator.predict(noise)

# reinstate scale of pixel values to [0:1] and reshape
#res = 0.5 * (res + 1)
res = res.reshape((1024, 1024, 3))

# Visualize result
plt.figure(figsize=(20, 20))
plt.imshow(res)
plt.title(f'Example Generator Output')
plt.axis('off')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:11 out of the last 2097 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f68004b79d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (-0.5, 1023.5, 1023.5, -0.5)
